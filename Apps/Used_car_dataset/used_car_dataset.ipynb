# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('used_cars_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7253 entries, 0 to 7252
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   S.No.              7253 non-null   int64
#  1   Name               7253 non-null   object
#  2   Location           7253 non-null   object
#  3   Year               7253 non-null   int64
#  4   Kilometers_Driven  7253 non-null   int64
#  5   Fuel_Type          7253 non-null   object
#  6   Transmission       7253 non-null   object
#  7   Owner_Type         7253 non-null   object
#  8   Mileage            7251 non-null   object
#  9   Engine             7207 non-null   object
#  10  Power              7207 non-null   object
#  11  Seats              7200 non-null   float64
#  12  New_Price          1006 non-null   object
#  13  Price              6019 non-null   float64
# dtypes: float64(2), int64(3), object(9)
# memory usage: 793.4+ KB

# %%
df.describe(include='all')
# Out:
#               S.No.                    Name Location         Year  \
# count   7253.000000                    7253     7253  7253.000000
# unique          NaN                    2041       11          NaN
# top             NaN  Mahindra XUV500 W8 2WD   Mumbai          NaN
# freq            NaN                      55      949          NaN
# mean    3626.000000                     NaN      NaN  2013.365366
# std     2093.905084                     NaN      NaN     3.254421
# min        0.000000                     NaN      NaN  1996.000000
# 25%     1813.000000                     NaN      NaN  2011.000000
# 50%     3626.000000                     NaN      NaN  2014.000000
# 75%     5439.000000                     NaN      NaN  2016.000000
# max     7252.000000                     NaN      NaN  2019.000000
#
#         Kilometers_Driven Fuel_Type Transmission Owner_Type    Mileage  \
# count        7.253000e+03      7253         7253       7253       7251
# ...

# %%
df.columns
# Out:
# Index(['S.No.', 'Name', 'Location', 'Year', 'Kilometers_Driven', 'Fuel_Type',
#        'Transmission', 'Owner_Type', 'Mileage', 'Engine', 'Power', 'Seats',
#        'New_Price', 'Price'],
#       dtype='object')

# %%
df.head()
# Out:
#    S.No.                              Name    Location  Year  \
# 0      0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1      1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2      2                      Honda Jazz V     Chennai  2011
# 3      3                 Maruti Ertiga VDI     Chennai  2012
# 4      4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 0              72000       CNG       Manual      First  26.6 km/kg   998 CC
# 1              41000    Diesel       Manual      First  19.67 kmpl  1582 CC
# 2              46000    Petrol       Manual      First   18.2 kmpl  1199 CC
# 3              87000    Diesel       Manual      First  20.77 kmpl  1248 CC
# 4              40670    Diesel    Automatic     Second   15.2 kmpl  1968 CC
#
#        Power  Seats  New_Price  Price
# 0  58.16 bhp    5.0        NaN   1.75
# 1  126.2 bhp    5.0        NaN  12.50
# ...

# %%
target_col = 'Price'
cat_cols = ['Location','Year','Fuel_Type','Transmission','Owner_Type']
num_cols = ['Kilometers_Driven','Mileage','Engine','Power','Seats']
drop_cols = [['New_Price']]

# %%
for col in df.columns:
    print(f'{col}:{df[col].nunique()}')
    print(df[col].unique())
    print('-'*20)
# Out:
# S.No.:7253
# [   0    1    2 ... 7250 7251 7252]
# --------------------
# Name:2041
# ['Maruti Wagon R LXI CNG' 'Hyundai Creta 1.6 CRDi SX Option'
#  'Honda Jazz V' ... 'Ford EcoSport 1.5 Petrol Ambiente'
#  'Jeep Compass 1.4 Sport' 'Hyundai Elite i20 Magna Plus']
# --------------------
# Location:11
# ['Mumbai' 'Pune' 'Chennai' 'Coimbatore' 'Hyderabad' 'Jaipur' 'Kochi'
#  'Kolkata' 'Delhi' 'Bangalore' 'Ahmedabad']
# --------------------
# Year:23
# [2010 2015 2011 2012 2013 2016 2018 2014 2017 2007 2009 2008 2019 2006
#  2005 2004 2002 2000 2003 1999 2001 1998 1996]
# --------------------
# Kilometers_Driven:3660
# [72000 41000 46000 ... 89411 52262 72443]
# --------------------
# Fuel_Type:5
# ['CNG' 'Diesel' 'Petrol' 'LPG' 'Electric']
# --------------------
# Transmission:2
# ['Manual' 'Automatic']
# --------------------
# Owner_Type:4
# ['First' 'Second' 'Fourth & Above' 'Third']
# --------------------
# Mileage:450
# ...

# %%
df.head()
# Out:
#    S.No.                              Name    Location  Year  \
# 0      0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1      1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2      2                      Honda Jazz V     Chennai  2011
# 3      3                 Maruti Ertiga VDI     Chennai  2012
# 4      4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 0              72000       CNG       Manual      First  26.6 km/kg   998 CC
# 1              41000    Diesel       Manual      First  19.67 kmpl  1582 CC
# 2              46000    Petrol       Manual      First   18.2 kmpl  1199 CC
# 3              87000    Diesel       Manual      First  20.77 kmpl  1248 CC
# 4              40670    Diesel    Automatic     Second   15.2 kmpl  1968 CC
#
#        Power  Seats  New_Price  Price
# 0  58.16 bhp    5.0        NaN   1.75
# 1  126.2 bhp    5.0        NaN  12.50
# ...

# %%
def cat_analyze(col):
    print(col)
    print(df[col].value_counts().sort_index(ascending=False))
    sns.countplot(data = df, y=col)
    plt.show()

for col in cat_cols:
    cat_analyze(col)
# Out:
# Location
# Pune          765
# Mumbai        949
# Kolkata       654
# Kochi         772
# Jaipur        499
# Hyderabad     876
# Delhi         660
# Coimbatore    772
# Chennai       591
# Bangalore     440
# Ahmedabad     275
# Name: Location, dtype: int64
# Year
# 2019    119
# 2018    361
# 2017    709
# 2016    886
# 2015    929
# 2014    925
# 2013    791
# 2012    690
# 2011    579
# 2010    407
# 2009    252
# 2008    207
# 2007    148
# 2006     89
# 2005     68
# 2004     35
# 2003     20
# 2002     18
# 2001      8
# 2000      5
# 1999      2
# 1998      4
# 1996      1
# Name: Year, dtype: int64
# Fuel_Type
# Petrol      3325
# LPG           12
# Electric       2
# Diesel      3852
# CNG           62
# Name: Fuel_Type, dtype: int64
# Transmission
# Manual       5204
# Automatic    2049
# Name: Transmission, dtype: int64
# Owner_Type
# Third              137
# Second            1152
# Fourth & Above      12
# First             5952
# Name: Owner_Type, dtype: int64

# %%
df['Mileage'].head()
# Out:
# 0    26.6 km/kg
# 1    19.67 kmpl
# 2     18.2 kmpl
# 3    20.77 kmpl
# 4     15.2 kmpl
# Name: Mileage, dtype: object

# %%
#Because of mileage,engine,power we have to preprocess data we need int data

# %%
df.head()
# Out:
#    S.No.                              Name    Location  Year  \
# 0      0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1      1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2      2                      Honda Jazz V     Chennai  2011
# 3      3                 Maruti Ertiga VDI     Chennai  2012
# 4      4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
#
#    Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage   Engine  \
# 0              72000       CNG       Manual      First  26.6 km/kg   998 CC
# 1              41000    Diesel       Manual      First  19.67 kmpl  1582 CC
# 2              46000    Petrol       Manual      First   18.2 kmpl  1199 CC
# 3              87000    Diesel       Manual      First  20.77 kmpl  1248 CC
# 4              40670    Diesel    Automatic     Second   15.2 kmpl  1968 CC
#
#        Power  Seats  New_Price  Price
# 0  58.16 bhp    5.0        NaN   1.75
# 1  126.2 bhp    5.0        NaN  12.50
# ...

# %%
mileage=df['Mileage'].str.split().str.get(0)
mileage.sample(5)
# Out:
# 33       12.4
# 1887     18.5
# 53       28.4
# 5506     26.2
# 1266    20.92
# Name: Mileage, dtype: object

# %%
pd.isnull(mileage).sum()
# Out:
# 2

# %%
# We have Missing Data so we have to handle data

# %%
#Checking Missing data
100*pd.isnull(df).sum()/len(df)
# Out:
# S.No.                 0.000000
# Name                  0.000000
# Location              0.000000
# Year                  0.000000
# Kilometers_Driven     0.000000
# Fuel_Type             0.000000
# Transmission          0.000000
# Owner_Type            0.000000
# Mileage               0.027575
# Engine                0.634220
# Power                 0.634220
# Seats                 0.730732
# New_Price            86.129877
# Price                17.013650
# dtype: float64

# %%
df.drop(drop_cols,axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\ML Training\Apps\Used_car_dataset\used_car_dataset.ipynb Cell 18 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/ML%20Training/Apps/Used_car_dataset/used_car_dataset.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> df.drop(drop_cols,axis=1,inplace=True)
#
# File c:\Users\adipr\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File c:\Users\adipr\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
# Again checking after droping
100*pd.isnull(df).sum()/len(df)
# Out:
# S.No.                 0.000000
# Name                  0.000000
# Location              0.000000
# Year                  0.000000
# Kilometers_Driven     0.000000
# Fuel_Type             0.000000
# Transmission          0.000000
# Owner_Type            0.000000
# Mileage               0.027575
# Engine                0.634220
# Power                 0.634220
# Seats                 0.730732
# Price                17.013650
# dtype: float64

# %%
df['Name'].str.lower().str.split().str.get(0).value_counts()
# Out:
# maruti           1444
# hyundai          1340
# honda             743
# toyota            507
# mercedes-benz     380
# volkswagen        374
# ford              351
# mahindra          331
# bmw               312
# audi              285
# tata              228
# skoda             202
# renault           170
# chevrolet         151
# nissan            117
# land               67
# jaguar             48
# fiat               38
# mitsubishi         36
# mini               31
# volvo              28
# porsche            19
# jeep               19
# datsun             17
# isuzu               5
# force               3
# bentley             2
# smart               1
# ambassador          1
# lamborghini         1
# hindustan           1
# opelcorsa           1
# Name: Name, dtype: int64

# %% [markdown]
# # Drop the Missing Entries

# %%
df.dropna()#This will drop all the missing entries in columns
# Out:
#       S.No.                              Name    Location  Year  \
# 0         0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1         1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2         2                      Honda Jazz V     Chennai  2011
# 3         3                 Maruti Ertiga VDI     Chennai  2012
# 4         4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...     ...                               ...         ...   ...
# 6014   6014                  Maruti Swift VDI       Delhi  2014
# 6015   6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016   6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017   6017                Maruti Wagon R VXI     Kolkata  2013
# 6018   6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 0                 72000       CNG       Manual      First  26.6 km/kg
# ...

# %%
#Treating the car data first
df['Power'].apply(lambda x: np.nan if pd.isnull(x) else( (np.nan) if 'null' in x.lower() else x))
# Out:
# 0       58.16 bhp
# 1       126.2 bhp
# 2        88.7 bhp
# 3       88.76 bhp
# 4       140.8 bhp
#           ...
# 7248    103.6 bhp
# 7249    103.6 bhp
# 7250     63.1 bhp
# 7251    103.6 bhp
# 7252      170 bhp
# Name: Power, Length: 7253, dtype: object

# %%
df1=df.dropna(thresh=10)
df0=df.dropna()

# %%
df0.shape,df1.shape
# Out:
# ((5975, 13), (7243, 13))

# %%
#Only Method is to be used here remove all the missing entries
cars=df.dropna()
cars.shape
# Out:
# (5975, 13)

# %%
cars = df[~pd.isnull(df['Price'])]
cars
# Out:
#       S.No.                              Name    Location  Year  \
# 0         0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1         1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2         2                      Honda Jazz V     Chennai  2011
# 3         3                 Maruti Ertiga VDI     Chennai  2012
# 4         4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...     ...                               ...         ...   ...
# 6014   6014                  Maruti Swift VDI       Delhi  2014
# 6015   6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016   6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017   6017                Maruti Wagon R VXI     Kolkata  2013
# 6018   6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 0                 72000       CNG       Manual      First  26.6 km/kg
# ...

# %%
#two methods to use 
# cars['Mileage'].str.split().str.get(0).astype(float)
cars["Mileage"]=cars["Mileage"].str.split().str.get(0).astype(float)
cars["Power"]=cars["Power"].str.split().str.get(0).astype(float)
cars["Engine"]=cars["Engine"].str.split().str.get(0).astype(float)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\ML Training\Apps\Used_car_dataset\used_car_dataset.ipynb Cell 28 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/ML%20Training/Apps/Used_car_dataset/used_car_dataset.ipynb#X56sZmlsZQ%3D%3D?line=0'>1</a> #two methods to use
#       <a href='vscode-notebook-cell:/c%3A/ML%20Training/Apps/Used_car_dataset/used_car_dataset.ipynb#X56sZmlsZQ%3D%3D?line=1'>2</a> # cars['Mileage'].str.split().str.get(0).astype(float)
# ----> <a href='vscode-notebook-cell:/c%3A/ML%20Training/Apps/Used_car_dataset/used_car_dataset.ipynb#X56sZmlsZQ%3D%3D?line=2'>3</a> cars["Mileage"]=cars["Mileage"].str.split().str.get(0).astype(float)
#       <a href='vscode-notebook-cell:/c%3A/ML%20Training/Apps/Used_car_dataset/used_car_dataset.ipynb#X56sZmlsZQ%3D%3D?line=3'>4</a> cars["Power"]=cars["Power"].str.split().str.get(0).astype(float)
# ...

# %%
100*pd.isnull(cars).sum()/len(df)
# Out:
# S.No.                0.000000
# Name                 0.000000
# Location             0.000000
# Year                 0.000000
# Kilometers_Driven    0.000000
# Fuel_Type            0.000000
# Transmission         0.000000
# Owner_Type           0.000000
# Mileage              0.027575
# Engine               0.496346
# Power                0.496346
# Seats                0.579071
# Price                0.000000
# dtype: float64

# %%
100*pd.isnull(cars).sum()/len(cars)
# Out:
# S.No.                0.0
# Name                 0.0
# Location             0.0
# Year                 0.0
# Kilometers_Driven    0.0
# Fuel_Type            0.0
# Transmission         0.0
# Owner_Type           0.0
# Mileage              0.0
# Engine               0.0
# Power                0.0
# Seats                0.0
# Price                0.0
# dtype: float64

# %%
cars
# Out:
#       S.No.                              Name    Location  Year  \
# 0         0            Maruti Wagon R LXI CNG      Mumbai  2010
# 1         1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015
# 2         2                      Honda Jazz V     Chennai  2011
# 3         3                 Maruti Ertiga VDI     Chennai  2012
# 4         4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013
# ...     ...                               ...         ...   ...
# 6014   6014                  Maruti Swift VDI       Delhi  2014
# 6015   6015          Hyundai Xcent 1.1 CRDi S      Jaipur  2015
# 6016   6016             Mahindra Xylo D4 BSIV      Jaipur  2012
# 6017   6017                Maruti Wagon R VXI     Kolkata  2013
# 6018   6018             Chevrolet Beat Diesel   Hyderabad  2011
#
#       Kilometers_Driven Fuel_Type Transmission Owner_Type     Mileage  \
# 0                 72000       CNG       Manual      First  26.6 km/kg
# ...
