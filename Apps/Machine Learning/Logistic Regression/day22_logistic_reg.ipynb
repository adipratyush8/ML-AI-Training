# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('titanic_train.csv')
df.sample(3)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 96            97         0       1                 Goldschmidt, Mr. George B
# 301          302         1       3                        McCoy, Mr. Bernard
# 52            53         1       1  Harper, Mrs. Henry Sleeper (Myna Haxtun)
#
#         Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 96     male  71.0      0      0  PC 17754  34.6542    A5        C
# 301    male   NaN      2      0    367226  23.2500   NaN        Q
# 52   female  49.0      1      0  PC 17572  76.7292   D33        C

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# ## EDA

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
target_col = 'Survived'
cat_cols = ['Pclass','Sex','Embarked']
num_cols = ['Age','SibSp','Parch','Fare']
drop_cols = ['PassengerId','Name','Ticket','Cabin']

# %% [markdown]
# Univariate Analysis

# %%
def cat_analyze(col):
    print(col)
    print(df[col].value_counts().sort_index())
    sns.countplot(data = df, x=col)
    plt.show()

for col in cat_cols:
    cat_analyze(col)
# Out:
# Pclass
# 1    216
# 2    184
# 3    491
# Name: Pclass, dtype: int64
# Sex
# female    314
# male      577
# Name: Sex, dtype: int64
# Embarked
# C    168
# Q     77
# S    644
# Name: Embarked, dtype: int64

# %%
def num_analyze(col):
    print(col)
    sns.distplot(df[col])
    plt.show()

for col in num_cols:
    num_analyze(col)
# Out:
# Age
# SibSp
# Parch
# Fare

# %% [markdown]
# Bivariate Analysis

# %%
def cat_bivariate(col):
    print(col)
    print(df.groupby(target_col)[col].value_counts().sort_index())
    sns.countplot(data=df,x=col,hue=target_col)
    plt.show()
for col in cat_cols:
    cat_bivariate(col)
# Out:
# Pclass
# Survived  Pclass
# 0         1          80
#           2          97
#           3         372
# 1         1         136
#           2          87
#           3         119
# Name: Pclass, dtype: int64
# Sex
# Survived  Sex
# 0         female     81
#           male      468
# 1         female    233
#           male      109
# Name: Sex, dtype: int64
# Embarked
# Survived  Embarked
# 0         C            75
#           Q            47
#           S           427
# 1         C            93
#           Q            30
#           S           217
# Name: Embarked, dtype: int64

# %%
def num_bivariate(col):
    print(col)
    plt.figure(figsize=(15,4))
    plt.subplot(1,3,1)    
    sns.barplot(data=df,x=target_col,y=col)
    plt.subplot(1,3,2)
    sns.boxplot(data=df,x=target_col, y=col)
    plt.subplot(1,3,3)
    sns.violinplot(data=df,x=target_col, y=col)
    plt.show()
for col in num_cols:
    num_bivariate(col)
# Out:
# Age
# SibSp
# Parch
# Fare

# %%
sns.heatmap(df[num_cols].corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# multivariate

# %%
from random import choice
p_list = ['Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'crest', 'crest_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'flare', 'flare_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'hot', 'hot_r', 'hsv', 'hsv_r', 'icefire', 'icefire_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'mako', 'mako_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 'rainbow_r', 'rocket', 'rocket_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 'turbo', 'turbo_r', 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 'viridis_r', 'vlag', 'vlag_r', 'winter', 'winter_r']

# %%
for col in cat_cols:
    if col == target_col:
        continue
    for ncol in num_cols:
        plt.figure(figsize=(18,3))
        plt.suptitle(f'{col} vs {ncol}')
        plt.subplot(1,3,1)
        sns.boxplot(
            data = df, x = col, y = ncol, 
            hue = target_col, palette=choice(p_list))
        plt.subplot(1,3,2)
        sns.violinplot(
            data=df, x = col, y = ncol, 
            hue = target_col, palette=choice(p_list))
        plt.subplot(1,3,3)
        sns.barplot(
            data = df, x = col, y = ncol, 
            hue = target_col, palette=choice(p_list))
        plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\ML Training\Apps\Machine Learning\Logistic Regression\day22_logistic_reg.ipynb Cell 17 in <cell line: 1>()
#      <a href='vscode-notebook-cell:/c%3A/ML%20Training/Apps/Machine%20Learning/Logistic%20Regression/day22_logistic_reg.ipynb#X22sZmlsZQ%3D%3D?line=11'>12</a> sns.violinplot(
#      <a href='vscode-notebook-cell:/c%3A/ML%20Training/Apps/Machine%20Learning/Logistic%20Regression/day22_logistic_reg.ipynb#X22sZmlsZQ%3D%3D?line=12'>13</a>     data=df, x = col, y = ncol,
#      <a href='vscode-notebook-cell:/c%3A/ML%20Training/Apps/Machine%20Learning/Logistic%20Regression/day22_logistic_reg.ipynb#X22sZmlsZQ%3D%3D?line=13'>14</a>     hue = target_col, palette=choice(p_list))
#      <a href='vscode-notebook-cell:/c%3A/ML%20Training/Apps/Machine%20Learning/Logistic%20Regression/day22_logistic_reg.ipynb#X22sZmlsZQ%3D%3D?line=14'>15</a> plt.subplot(1,3,3)
# ---> <a href='vscode-notebook-cell:/c%3A/ML%20Training/Apps/Machine%20Learning/Logistic%20Regression/day22_logistic_reg.ipynb#X22sZmlsZQ%3D%3D?line=15'>16</a> sns.barplot(
#      <a href='vscode-notebook-cell:/c%3A/ML%20Training/Apps/Machine%20Learning/Logistic%20Regression/day22_logistic_reg.ipynb#X22sZmlsZQ%3D%3D?line=16'>17</a>     data = df, x = col, y = ncol,
#      <a href='vscode-notebook-cell:/c%3A/ML%20Training/Apps/Machine%20Learning/Logistic%20Regression/day22_logistic_reg.ipynb#X22sZmlsZQ%3D%3D?line=17'>18</a>     hue = target_col, palette=choice(p_list))
#      <a href='vscode-notebook-cell:/c%3A/ML%20Training/Apps/Machine%20Learning/Logistic%20Regression/day22_logistic_reg.ipynb#X22sZmlsZQ%3D%3D?line=18'>19</a> plt.show()
#
# File c:\Users\adipr\anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File c:\Users\adipr\anaconda3\lib\site-packages\seaborn\categorical.py:3182, in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3169 @_deprecate_positional_args
#    3170 def barplot(
#    3171     *,
#    (...)
#    3179     **kwargs,
#    3180 ):
# -> 3182     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    3183                           estimator, ci, n_boot, units, seed,
#    3184                           orient, color, palette, saturation,
#    3185                           errcolor, errwidth, capsize, dodge)
#    3187     if ax is None:
#    3188         ax = plt.gca()
#
# File c:\Users\adipr\anaconda3\lib\site-packages\seaborn\categorical.py:1586, in _BarPlotter.__init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1583 """Initialize the plotter."""
#    1584 self.establish_variables(x, y, hue, data, orient,
#    1585                          order, hue_order, units)
# -> 1586 self.establish_colors(color, palette, saturation)
#    1587 self.estimate_statistic(estimator, ci, n_boot, seed)
#    1589 self.dodge = dodge
#
# File c:\Users\adipr\anaconda3\lib\site-packages\seaborn\categorical.py:308, in _CategoricalPlotter.establish_colors(self, color, palette, saturation)
#     305             levels = self.hue_names
#     306         palette = [palette[l] for l in levels]
# --> 308     colors = color_palette(palette, n_colors)
#     310 # Desaturate a bit because these are patches
#     311 if saturation < 1:
#
# File c:\Users\adipr\anaconda3\lib\site-packages\seaborn\palettes.py:174, in color_palette(palette, n_colors, desat, as_cmap)
#     170     palette = husl_palette(n_colors, as_cmap=as_cmap)
#     172 elif palette.lower() == "jet":
#     173     # Paternalism
# --> 174     raise ValueError("No.")
#     176 elif palette.startswith("ch:"):
#     177     # Cubehelix palette with params specified in string
#     178     args, kwargs = _parse_cubehelix_args(palette)
#
# ValueError: No.

# %%
df.drop(drop_cols, axis=1,inplace=True)

# %% [markdown]
# ##### Missing Data

# %%
# Missing Data Identification
pd.isnull(df)
# Out:
#      Survived  Pclass    Sex    Age  SibSp  Parch   Fare  Embarked
# 0       False   False  False  False  False  False  False     False
# 1       False   False  False  False  False  False  False     False
# 2       False   False  False  False  False  False  False     False
# 3       False   False  False  False  False  False  False     False
# 4       False   False  False  False  False  False  False     False
# ..        ...     ...    ...    ...    ...    ...    ...       ...
# 886     False   False  False  False  False  False  False     False
# 887     False   False  False  False  False  False  False     False
# 888     False   False  False   True  False  False  False     False
# 889     False   False  False  False  False  False  False     False
# 890     False   False  False  False  False  False  False     False
#
# [891 rows x 8 columns]

# %%
pd.isnull(df).sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Embarked      2
# dtype: int64

# %%
100*pd.isnull(df).sum()/len(df)
# Out:
# Survived     0.000000
# Pclass       0.000000
# Sex          0.000000
# Age         19.865320
# SibSp        0.000000
# Parch        0.000000
# Fare         0.000000
# Embarked     0.224467
# dtype: float64

# %% [markdown]
# Missing Data Strategy
# - Identify Missing Data
# - Discard the columns having too much of missing data (>25%)
# - Treat/Impute the missing entries in columns
#     - Try to fill fake entries which doesn't impact overall data
#         - Fill using Mean Values (numerical data)
#         - Fill using some imputers (categorical data)
# - Discard the rows having missing entries, if the missing entries are too less (<5%)

# %%
plt.figure(figsize=(18,5))
sns.heatmap(pd.isnull(df))
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(18,5))
sns.heatmap(pd.isnull(df))
# Out:
# <AxesSubplot:>

# %%
sns.set_style('whitegrid')

# %%
sns.barplot(data=df, x='Survived', y='Age')
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Age'>

# %%
df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df['Age'].mean()
# Out:
# 29.69911764705882

# %%
df.columns
# Out:
# Index(['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare',
#        'Embarked'],
#       dtype='object')

# %%
df['Age'].fillna(0)
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     0.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df['Age'].fillna(df['Age'].mean()).mean()
# Out:
# 29.699117647058763

# %%
sns.barplot(data=df,y='Age',x='Pclass',hue='Sex')
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %%
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
# Impute the fake entries in missing Age Information
def age_imputer(data):
    age = data['Age']
    pclass = data['Pclass']
    sex = data['Sex']

    if pd.isnull(age):
        return df['Age'][(df['Pclass']==pclass)&(df['Sex']==sex)].mean()
    else:
        return age

df['Age'] = df.apply(age_imputer, axis = 1)

# %%
plt.figure(figsize=(18,10))
sns.heatmap(pd.isnull(df))
# Out:
# <AxesSubplot:>

# %%
# Dropping missing entries which were very less (in Embarked Column)
df.dropna(inplace=True)

# %%
plt.figure(figsize=(8,5))
sns.heatmap(pd.isnull(df))
# Out:
# <AxesSubplot:>

# %%
100*pd.isnull(df).sum()/len(df)
# Out:
# Survived    0.0
# Pclass      0.0
# Sex         0.0
# Age         0.0
# SibSp       0.0
# Parch       0.0
# Fare        0.0
# Embarked    0.0
# dtype: float64

# %%
df.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %% [markdown]
# String Data Preprocessing / Creating Dummy for String

# %%
data = pd.get_dummies(df).drop('Sex_female',axis=1)

# %%
data.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare  Sex_male  Embarked_C  \
# 0         0       3  22.0      1      0   7.2500         1           0
# 1         1       1  38.0      1      0  71.2833         0           1
# 2         1       3  26.0      0      0   7.9250         0           0
# 3         1       1  35.0      1      0  53.1000         0           0
# 4         0       3  35.0      0      0   8.0500         1           0
#
#    Embarked_Q  Embarked_S
# 0           0           1
# 1           0           0
# 2           0           1
# 3           0           1
# 4           0           1

# %%
sns.pairplot(data)

# %%
target = data[target_col]
features = data.drop(target_col, axis=1)

# %%
target.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Survived, dtype: int64

# %%
features.head()
# Out:
#    Pclass   Age  SibSp  Parch     Fare  Sex_male  Embarked_C  Embarked_Q  \
# 0       3  22.0      1      0   7.2500         1           0           0
# 1       1  38.0      1      0  71.2833         0           1           0
# 2       3  26.0      0      0   7.9250         0           0           0
# 3       1  35.0      1      0  53.1000         0           0           0
# 4       3  35.0      0      0   8.0500         1           0           0
#
#    Embarked_S
# 0           1
# 1           0
# 2           1
# 3           1
# 4           1

# %% [markdown]
# Why we decided Logistic Regression?
# 1. Initially we thought of doing with Pairplot, but since its a categorical data in target, its not helpful
# 2. Since its <b style="color:yellow;">binary categorical target</b> and Features are mixtures of <b style="color:yellow;">numerical</b> and <b style="color:yellow;">categorical</b> both, then I can think of Logistic Regression (Classification)

# %% [markdown]
# # Machine Learning Template

# %% [markdown]
# #### Data Splitting

# %%
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(features, target, test_size=0.25, random_state=101)

# %% [markdown]
# #### Model Creation & Training

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(xtrain,ytrain)
# Out:
# LogisticRegression()

# %%
ytrain
# Out:
# 127    1
# 133    1
# 619    0
# 439    0
# 374    0
#       ..
# 576    1
# 840    0
# 338    1
# 524    0
# 865    1
# Name: Survived, Length: 666, dtype: int64

# %% [markdown]
# #### Model Evaluation

# %%
print(round(100 * model.score(xtest, ytest)),'%')
# Out:
# 83 %

# %%
# Confusion Matrix and Classification Report
from sklearn.metrics import confusion_matrix, classification_report
ytest_pred = model.predict(xtest)
sns.heatmap(confusion_matrix(ytest,ytest_pred), annot = True, fmt='d')
plt.show()
print(classification_report(ytest,ytest_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.93      0.87       136
#            1       0.86      0.69      0.76        87
#
#     accuracy                           0.83       223
#    macro avg       0.84      0.81      0.82       223
# weighted avg       0.84      0.83      0.83       223

# %%
print(ytest.shape)
ytest.value_counts()
# Out:
# (223,)
# 0    136
# 1     87
# Name: Survived, dtype: int64

# %%
pd.Series(ytest_pred).value_counts()
# Out:
# 0    153
# 1     70
# dtype: int64

# %% [markdown]
# # Improving our Biased Model
# 1. By Balancing
# 2. By Hyperparameter Tuning
# 3. Cross Validation

# %%
# Putting Class Weights/Hyperparam
model1 = LogisticRegression(class_weight={0:0.7,1:0.3},random_state=101)
model1.fit(xtrain,ytrain)
print(classification_report(ytest,model1.predict(xtest)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.99      0.85       136
#            1       0.97      0.45      0.61        87
#
#     accuracy                           0.78       223
#    macro avg       0.86      0.72      0.73       223
# weighted avg       0.83      0.78      0.76       223

# %%
#HyperHam
for algo in ['newton-cg','lbfgs','liblinear','sag','saga']:
    modelalgo = LogisticRegression(solver=algo,random_state=101)
    print(algo)
    modelalgo.fit(xtrain,ytrain)
    print(classification_report(ytest,modelalgo.predict(xtest)))
# Out:
# newton-cg
#               precision    recall  f1-score   support
#
#            0       0.82      0.93      0.88       136
#            1       0.87      0.69      0.77        87
#
#     accuracy                           0.84       223
#    macro avg       0.85      0.81      0.82       223
# weighted avg       0.84      0.84      0.83       223
#
# lbfgs
#               precision    recall  f1-score   support
#
#            0       0.82      0.93      0.87       136
#            1       0.86      0.69      0.76        87
#
#     accuracy                           0.83       223
#    macro avg       0.84      0.81      0.82       223
# weighted avg       0.84      0.83      0.83       223
#
# liblinear
#               precision    recall  f1-score   support
#
#            0       0.82      0.93      0.87       136
#            1       0.86      0.68      0.76        87
#
#     accuracy                           0.83       223
#    macro avg       0.84      0.80      0.81       223
# weighted avg       0.83      0.83      0.83       223
#
# sag
#               precision    recall  f1-score   support
#
#            0       0.67      0.95      0.78       136
#            1       0.77      0.26      0.39        87
#
#     accuracy                           0.68       223
#    macro avg       0.72      0.61      0.59       223
# weighted avg       0.71      0.68      0.63       223
#
# saga
#               precision    recall  f1-score   support
#
#            0       0.68      0.93      0.79       136
#            1       0.76      0.32      0.45        87
#
#     accuracy                           0.70       223
#    macro avg       0.72      0.63      0.62       223
# weighted avg       0.71      0.70      0.66       223

# %%
from sklearn.tree import DecisionTreeClassifier
model_dt=DecisionTreeClassifier()
model_dt.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
print(classification_report(ytest,model_dt.predict(xtest)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.79      0.80       136
#            1       0.69      0.71      0.70        87
#
#     accuracy                           0.76       223
#    macro avg       0.75      0.75      0.75       223
# weighted avg       0.76      0.76      0.76       223

# %%
print(model_dt.feature_importances_,index=xtrain.columns,columns=['Importance']).sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\ML Training\Apps\Machine Learning\Logistic Regression\day22_logistic_reg.ipynb Cell 65 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/ML%20Training/Apps/Machine%20Learning/Logistic%20Regression/day22_logistic_reg.ipynb#Y122sZmlsZQ%3D%3D?line=0'>1</a> print(model_dt.feature_importances_,index=xtrain.columns,columns=['Importance']).sort_values(ascending=False)
#
# TypeError: 'index' is an invalid keyword argument for print()

# %%
from sklearn.ensemble import RandomForestClassifier
model_rf=RandomForestClassifier()
model_rf.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier()

# %%
print(classification_report(ytest,model_rf.predict(xtest)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.88      0.86       136
#            1       0.80      0.75      0.77        87
#
#     accuracy                           0.83       223
#    macro avg       0.82      0.81      0.82       223
# weighted avg       0.83      0.83      0.83       223

# %%
pd.to_pickle(model,'SurvivalPrediction.pickle')
pd.to_pickle(model_rf,'SurvivalPredictionRf.pickle')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\ML Training\Logistic Regression\day22_logistic_reg.ipynb Cell 68 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/ML%20Training/Logistic%20Regression/day22_logistic_reg.ipynb#Y123sZmlsZQ%3D%3D?line=0'>1</a> pd.to_pickle(model,'SurvivalPrediction.pickle')
# ----> <a href='vscode-notebook-cell:/c%3A/ML%20Training/Logistic%20Regression/day22_logistic_reg.ipynb#Y123sZmlsZQ%3D%3D?line=1'>2</a> pd.to_pickle(model_rf,'SurvivalPredictionRf.pickle')
#
# NameError: name 'model_rf' is not defined

# %% [markdown]
# * After applying Various Algorithms it is observed that the best score is around 82% with Logistic Regression only
# * Also Random Forest Model can be used if we want less number of parameters
